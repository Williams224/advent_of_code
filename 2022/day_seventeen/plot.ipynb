# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('/Users/TimothyW/Fun/avent_of_code/real_data.csv')

# %%
fig = plt.figure()
ax = fig.gca()
ax.cla()
df.plot.scatter(x = 'rock_i', y= 'height', ax =ax)
ax.set_xlim(100,500)
ax.set_ylim(140,800)
# Out:
# (140.0, 800.0)

# %%
pd.set_option('display.max_rows', 100)
df['diff'] = df['height'] - df['height'].shift(1)
df.head(100)
# Out:
#     Unnamed: 0  rock_i  height  diff
# 0            0       0       1   NaN
# 1            1       1       3   2.0
# 2            2       2       5   2.0
# 3            3       3       9   4.0
# 4            4       4       9   0.0
# 5            5       5       9   0.0
# 6            6       6       9   0.0
# 7            7       7      10   1.0
# 8            8       8      10   0.0
# 9            9       9      10   0.0
# 10          10      10      10   0.0
# 11          11      11      13   3.0
# 12          12      12      13   0.0
# 13          13      13      16   3.0
# 14          14      14      16   0.0
# 15          15      15      17   1.0
# 16          16      16      20   3.0
# 17          17      17      22   2.0
# 18          18      18      23   1.0
# 19          19      19      25   2.0
# 20          20      20      26   1.0
# 21          21      21      28   2.0
# 22          22      22      31   3.0
# 23          23      23      33   2.0
# ...

# %%
m*1000000000000 + 1
# Out:
# 19462500000001.0

# %%
z = np.polyfit(x=df['rock_i'], y=df['height'], deg=1)
p = np.poly1d(z)

# %%
z
# Out:
# array([1.55651051, 9.68660347])

# %%
p(1000000000000)
# Out:
# 1556510506552.5837

# %%
df
# Out:
#        Unnamed: 0  rock_i  height
# 0               0       0       1
# 1               1       1       3
# 2               2       2       5
# 3               3       3       9
# 4               4       4       9
# ...           ...     ...     ...
# 24995       24995   24995   38916
# 24996       24996   24996   38919
# 24997       24997   24997   38921
# 24998       24998   24998   38925
# 24999       24999   24999   38925
#
# [25000 rows x 3 columns]

# %%
def guess_seq_len(seq):
    guess = 1
    max_len = int(len(seq) / 3)
    for x in range(2, max_len):
        first_diff = seq[x] - 0
        second_diff = seq[int(2*x)] - seq[x+1]
        third_diff = seq[int(3*x)] - seq[int(2*x) + 1]
        if first_diff == second_diff == third_diff:
            print(first_diff, second_diff, x)

# %%
guess_seq_len(df['height'])

# %%
def formula(x):
    return 53 * (x/35) + 3.8

# %%
formula(189)
# Out:
# 290.00000000000006

# %%
df['pred'] = df['rock_i'].apply(formula)
df['diff'] = df['height'] - df['pred']

# %%
df.head(100)
# Out:
#     Unnamed: 0  rock_i  height
# 0            0       0       1
# 1            1       1       3
# 2            2       2       5
# 3            3       3       9
# 4            4       4       9
# 5            5       5       9
# 6            6       6       9
# 7            7       7      10
# 8            8       8      10
# 9            9       9      10
# 10          10      10      10
# 11          11      11      13
# 12          12      12      13
# 13          13      13      16
# 14          14      14      16
# 15          15      15      17
# 16          16      16      20
# 17          17      17      22
# 18          18      18      23
# 19          19      19      25
# 20          20      20      26
# 21          21      21      28
# 22          22      22      31
# 23          23      23      33
# 24          24      24      33
# 25          25      25      34
# 26          26      26      37
# 27          27      27      37
# 28          28      28      39
# ...
